# %% [markdown]
# # Math Functions
#
# We can use the built-in function `abs` to get the absolute value of a number
#
# Мы можем использовать встроенную функцию abs, чтобы получить абсолютное значение числа.

# %%
x = -1
print(abs(x))
# Out:
# 1

# %%
abs(-200)
# Out:
# 200

# %% [markdown]
# We already know that exponentiation can be performed with ****** symbol, as well as with the function `pow`
#
# Мы уже знаем, что возведение в степень можно выполнить с помощью символа **, а также с помощью функции `pow`

# %%
x = 2
print('First method:', x ** 3)
print('Second method:', pow(x, 3))
# Out:
# First method: 8
# Second method: 8

# %% [markdown]
# We can use the function `round` to for rounding numbers.
#
# Для округления чисел можно использовать встроенную функцию `round`.

# %%
x = 1234.48918932
print('Rounding with 2 precision', round(x, 2))
print('Rounding with 3 precision', round(x, 3))
print('Rounding with 4 precision', round(x, 4))
# Out:
# Rounding with 2 precision 1234.49
# Rounding with 3 precision 1234.489
# Rounding with 4 precision 1234.4892

# %% [markdown]
# Suppose we want to get the minimum or maximum of a set of numbers, this can be done in the following way
#
# Предположим, что нам нужно определить минимальное или максимальное значение в наборе чисел. Это можно сделать следующим образом.

# %%
min(2, 3, 4, 5, 1, 6, 0)
# Out:
# 0

# %%
max(2, 3, 4, 5, 1, 6, 0)
# Out:
# 6

# %% [markdown]
# We can use `math` package, which comes with a variety of mathematical functions.
#
# For example, we can return
# * the **floor** (ամբողջ մաս) = the greatest integer less than or equal to the given number
# * the **ceil** = the smallest integer greater than or equal to the given number
#
#
# Мы можем использовать модуль `math`, который предоставляет широкий набор математических функций. Например:
#
# *  floor — возвращает наибольшее целое число, не превышающее данное
#
# *  ceil — возвращает наименьшее целое число, не меньшее данного

# %%
# first we import the package
import math

# %%
math.ceil(4.2)
# Out:
# 5

# %%
math.floor(5.2)
# Out:
# 5

# %% [markdown]
# We know that we can get the square-root (արմատ) of a number by using `x**0.5` as the exponent, but `sqrt` function also let's us do the same thing.
#
# Квадратный корень числа можно вычислить, возведя его в степень 0.5 (`x**0.5`), однако для этого также можно воспользоваться функцией `sqrt`.

# %%
x = 25
print('First method:', x**0.5)
print('Second method:', math.sqrt(x))
# Out:
# First method: 5.0
# Second method: 5.0

# %% [markdown]
# Here is an example for using the mathematical constant $e\approx 2.71828$ and $\pi\approx 3.14159$
#
# Ниже приведён пример использования математических констант $e\approx 2.71828$ и $\pi\approx 3.14159$

# %%
print('e =', math.exp(1))
print('e**2 =', math.exp(2))
# Out:
# e = 2.718281828459045
# e**2 = 7.38905609893065

# %%
print('pi =', math.pi)
# Out:
# pi = 3.141592653589793

# %% [markdown]
# To get the logarithm of a number, you can use the function `log2` for the base 2 log, `log10` for the base 10 and just `log` for the natural logatithm (with base `e`).
#
# Для вычисления логарифма числа используются функции `log2` (по основанию 2), `log10` (по основанию 10) и `log` — для натурального логарифма (с основанием e).

# %%
print(math.log10(2)) # log_2 2
# Out:
# 0.3010299956639812

# %%
math.sin(2)
# Out:
# 0.9092974268256817

# %% [markdown]
# # Comparison Operators
#
# |Operator | Description |
# --- | ---
# **>** or **<**	| greater than or less than
# **>=** or **<=**	| greater (less) than or equal
# **==**	| tests value equivalence
# **!=**	| not equal

# %%
print(5 > 2)
# Out:
# True

# %%
print(5 >= 5)
print(3 <= 2)
# Out:
# True
# False

# %%
print(2 == 5)
# Out:
# False

# %%
print(2 != 5)
# Out:
# True

# %% [markdown]
# **Remember** that we need to use two equality signs to check for equivalence, since we use one equality sign for variable assignment!
#
# Следует помнить, что для проверки равенства применяется оператор $==$, поскольку оператор $=$ используется для присваивания значения переменной.

# %% [markdown]
# There are three additional operators used to construct more complicated conditions: **and** , **or** , and
# **not**. Here are some examples:
#
# * **X and Y** - Is true if both X and Y are true
# * **X or Y** - Is true if either X or Y is true
# * **not X** - Is true if X is false
#
#
# Для построения составных логических условий используются три оператора: **and** , **or** , and
# **not**:
#
# * **X and Y** - логическое И
# * **X or Y** - логическое ИЛИ
# * **not X** - логическое НЕ

# %%
# condition constructed with 'and'
# returns true, if all of the subconditions are met
print(2 > 1 and 7 < 9)
# Out:
# True

# %%
print(2 > 1 and 7 > 9)
# Out:
# False

# %%
# condition constructed with 'or'
# returns true, if at least one of the subconditions are met
print(2 > 1 or 7 > 9)
# Out:
# True

# %% [markdown]
# **Order of operations:**
#
# **and** is done before **or**, so if you have a condition that contains both, you may need parentheses around the **or** condition. Think of **and** as being like *multiplication* and **or** as being like *addition*. Here is an example:
#
#
# Порядок выполнения операций:
#
# **and** выполняется раньше, чем **or**, поэтому если в условии присутствуют оба оператора, может понадобиться использовать скобки вокруг выражения с **or**.
# Можно представить **and** как умножение, а **or** как сложение.
#
# Вот пример:

# %%
a = 7
print((3 > 2 or 4 > 5) and a != 7)
# Out:
# False

# %%
print(3 > 2 or (4 > 5 and a != 7))
# Out:
# True

# %% [markdown]
# **not** is for negating a condition, for example if condition **A** is true, then **not A** is false.
#
#
# Оператор **not** используется для отрицания условия. Например, если условие **A** истинно, то**not A**будет ложным.

# %%
print(3 < 2)
print(not 3 < 2)
# Out:
# False
# True

# %% [markdown]
# In Python, we can also use an intuitive shortcut for testing whether a number belongs to the given interval, for example $[3,9]$
#
# В Python мы также можем использовать интуитивно понятную сокращённую запись для проверки того, принадлежит ли число заданному интервалу, например  $[3,9]$.

# %%
a = 5
print(a >= 3 and a <= 9)
# Out:
# True

# %%
print(3 <= a <= 9)
# Out:
# True

# %% [markdown]
# # If/else statement
#
# The If statement selects actions to perform. Here is the general form of it
#
# Оператор If выбирает действия, которые необходимо выполнить. Ниже приведена его общая форма.

# %%
''' if test1: # if test
  statements1 # Associated block
elif test2: # Optional elifs (else if)
  statements2
else: # Optional else
  statements3 '''

# %%
if 1: # remember that True = 1
  print('true')
# Out:
# true

# %%
if not 1:
  print('true')
else:
  print('false')
# Out:
# false

# %%
# as condition is not met it doesn't do anything
condition = 5
if condition > 6:
    print('bigger')

# %%
if condition > 3:
    print('bigger')
# Out:
# bigger

# %%
# else is all other cases
if condition > 6:
    print('bigger')
else:
    print('smaller')
# Out:
# smaller

# %%
if condition > 3:
    print('bigger')
else:
    print('smaller')
# Out:
# bigger

# %%
# You can add as many elifs as you want
# this is known as multiway branching
if condition > 5:
    print('bigger')
elif condition == 5:
    print('equal')
else:
    print('smaller')
# Out:
# equal

# %%
x = 10
if x == 10:
  print('x is 10')
elif x > 10:
  print('x is greater than 10')
else:
  print('x is less than 10')
# Out:
# x is 10

# %% [markdown]
# Later we will see that `dictionaries` can be used to for more flexible multiway branching.
#
# Позже мы увидим, что `dictionaries` можно использовать для более гибкого множественного ветвления.

# %%
condition = 5
if condition < 1 or condition == 5:
    print('sufficient')
else:
    print('insufficient')
# Out:
# sufficient

# %%
# You can check multiple conditions at once
condition = 5
if condition > 3 and condition < 7:
    print('between')
else:
    print('out')
# Out:
# between

# %%
condition = 5
if 3 < condition < 7:
    print('between')
else:
    print('out')
# Out:
# between

# %%
condition = 3
if condition < 1 or condition == 5:
    print('sufficient')
else:
    print('insufficient')
# Out:
# insufficient

# %%
if 6:
  print('hello')
# Out:
# hello

# %% [markdown]
# In Python
#
# * All objects have an inherent Boolean true or false value.
# * Any nonzero number or nonempty object is true.
# * Zero numbers, empty objects, and the special object **None** are considered false.
#
# В Python:
#
# * Все объекты имеют встроенное логическое значение — True или False.
#
# * Любое ненулевое число или непустой объект считается истинным (True).
#
# * Ноль, пустые объекты и специальный объект **None** считаются ложными (False)

# %%
if None:
  print('go')

# %%
if 0:
  print('go')

# %% [markdown]
# This can be done in one line as well.
#
# Это также можно сделать в одну строку.

# %%
x = 2
if x: print('hello')
# Out:
# hello

# %% [markdown]
# Python relies on indentation (whitespace at the beginning of a line) to define scope in the code. Other programming languages often use curly-brackets for this purpose. Python detects **block boundaries** automatically, by **line
# indentation** - that is, the empty space to the left of your code. All statements indented
# the same distance to the right belong to the same block of code.
#
# Python использует отступы (пробелы в начале строки) для определения области видимости кода.
# В других языках программирования для этой цели часто применяются фигурные скобки.
#
# Python автоматически определяет границы блоков кода по отступам строк, то есть по пустому пространству слева от кода.
# Все инструкции, имеющие одинаковый отступ, относятся к одному и тому же блоку кода.

# %%
x = 1
if x:
  y = 2
  if y:
    print('block2')
  print('block1')
print('block0')
# Out:
# block2
# block1
# block0

# %% [markdown]
# Let's see what happens when we don't keep the identation rules.
#
# Давайте посмотрим, что произойдёт, если мы не будем соблюдать правила отступов.

# %%
x = 1

if x:
  y = 2
  if y:
    print('block2')
  print('block1')
print('block0')
# Out:
# block2
# block1
# block0

# %% [markdown]
# Consistently indented code always satisfies Python's rules. Most text editors make it easy to follow
# Python's indentation model by automatically indenting code as you type it. **Mixing tabs and spaces can cause identation errors.**
#
#
# Код с последовательными и одинаковыми отступами всегда соответствует правилам Python.
# Большинство текстовых редакторов упрощают работу с отступами, автоматически добавляя их во время набора кода.
# Смешивание табуляции и пробелов может привести к ошибкам отступов.

# %% [markdown]
# ## IF/else Ternary Expression

# %%
x = 2
y = 0
z = 1
if x:
  a = y
else:
  a = z
print(a)
# Out:
# 0

# %%
a = y if x else z
print(a)
# Out:
# 0

# %% [markdown]
# The above simple if statement can be written in one line:
#
# Приведённый выше простой оператор if можно записать в одну строку.

# %%
# recall this example
condition = 7
if condition > 6:
  print('bigger')
else:
  print('smaller')
# Out:
# bigger

# %% [markdown]
# The same can be written using one line with the ternary expression.
#
# То же самое можно записать в одну строку, используя тернарное выражение.

# %%
print('bigger') if condition == 6 else print('smaller')
# Out:
# smaller

# %% [markdown]
# One line if else statement, with 3 conditions:
#
# Однострочный оператор if–else с тремя условиями:

# %%
a = 33
b = 33
print('A') if a > b else print('=') if a == b else print('B')
# Out:
# =

# %% [markdown]
# **if** statements cannot be empty, but if you for some reason have an if statement with no content, put in the **pass** statement to avoid getting an error.
#
# Операторы **if** не могут быть пустыми, однако если по какой-то причине условный оператор не содержит кода, используйте инструкцию  **pass**, чтобы избежать ошибки.

# %%
b = 200

if b > a:
  pass
print('hi')
# Out:
# hi

# %% [markdown]
# ## Exercises

# %% [markdown]
# 1. Write a program that asks the user to enter a grade 0-100 (number) and display the letter equivalent of it
#
#   Разработайте программу, которая принимает от пользователя числовую оценку вдиапазоне от 0 до 100 и отображает соответствующую ей буквенную оценку.
#
#   Գրել ծրագիր, որը օգտատիրոջից կողմից վերցնում է գնահատական՝ `0-100` միջակայքից և տպում է գնահատականին համապատասխան տառը ըստ նշված աղյուսակի։
#
# |Grade|Letter|
# | --- | --- |
# |[0,60] | F |
# |(60,70]| D |
# |(70,80]| C |
# |(80,90]| B |
# |(90,100]|A |

# %%
grade = eval(input('Enter the grade:'))

print(grade)

if type(grade) != int or grade < 0 or grade > 100:
  print('something')
elif 60 < grade <= 70:
  print('D')
elif 0 < grade <= 60:
  print('F')
elif 70 < grade <= 80:
  print('C')
elif 80 < grade <= 90:
  print('B')
else:
  print('A')

# %% [markdown]
# 2. Write a program that asks the user to enter a measure in grams. If the user enters a negative
# number, the program should tell the user that **the entry is invalid**. Otherwise, the program
# should convert the measure to kg and print out the result (1 kg is 1000 grams).
#
#    Напишите программу, которая запрашивает у пользователя массу в граммах. Если пользователь вводит отрицательное число, программа должна сообщить, что ввод недопустим. В противном случае программа должна перевести значение в килограммы и вывести результат (1 кг = 1000 граммов).
#
#   Գրել ծրագիր, որը օգտատիրոջ կողմից վերցնում է կշռային միավոր գրամի տեսքով, որը պետք է փոխակերպվի կիլոգրամի և տպի այն, եթե մուտքագրվում է բացասական թիվ ծրագիրը պետք է տպի **the entry is invalid**։

# %%
user_input = int(input('enter a number in grams'))
if user_input < 0:
    print('negative')
else:
    print(user_input/1000)

# %% [markdown]
# 3. Ask the user for time duration (for example in minutes). Then ask them what units the duration is in (**seconds**, **minutes** or **hours**). Your program should convert the duration in
# * seconds to minutes
# * minutes to hours
# * hours to days
#
# and display it with the corresponding unit.
#
#
# Запросите у пользователя длительность времени (например, в минутах). Затем спросите, в каких единицах измеряется эта длительность (seconds, minutes или hours). Программа должна выполнить преобразование:
#
# * из секунд в минуты
#
# * из минут в часы
#
# * из часов в дни
#
# и вывести результат с соответствующей единицей измерения.
#
#
#
#   Օգտատիրոջից պետք է վերցնել տևողության վերաբերյալ ժամային տվյալ (օրինակ՝ րոպեական), այնուհետև օգտատերը նշում է, թե որն է չափման միավորը (**seconds**, **minutes** կամ **hours**)։ Ձեր ծրագիրը պետք է փոխակերպեն տրված տևողությունը այլ չափման միավորի, ինչպես նշված է ստորև
# * seconds to minutes
# * minutes to hours
# * hours to days

# %%
user_input = int(input('enter time duration: '))
units = str(input('enter a unit like: seconds, minutes or hours'))
if units == 'seconds':
    print(user_input/60)
elif units == 'minutes':
    print(user_input/60)
elif units == 'hpure':
    print(user_input/24)
else:
    print('you are wrong')

# %% [markdown]
# 4. Write a program that asks the user for two numbers and prints **Close** if the numbers are
# within $0.001$ of each other and **Not close** otherwise.
#
# Напишите программу, которая запрашивает у пользователя два числа и выводит **Close**, если разница между ними меньше $0.001$, и **Not close** в противном случае.
#
#   Գրել ծրագիր, որը օգտատիրոջից վերցնում է երկու թիվ և տպում **Close**, եթե այդ թվերը իրարից $0.001$-ով են տարբերվում և **Not close**՝ հակառակ դեպքում։

# %%
a = eval(input('enter the first number: '))
b = eval(input('enter the second number: '))
if -0.001 < a-b < 0.001:
    print('close')
else:
    print('not close')

# %% [markdown]
# #дополнительные (supplementary) задачи для практики

# %% [markdown]
# 1. Напишите программу, которая запрашивает у пользователя число и выводит Positive, Negative или Zero в зависимости от его значения.

# %%
user_input = eval(input('enter a number: '))
if user_input > 0:
    print('possitive')
elif user_input == 0:
    print('zero')
else:
    print('negative')

# %% [markdown]
# 2. Запросите у пользователя температуру в градусах Цельсия и:
# * если температура < 0 → вывести `Freezing`
#
# * если 0–25 → вывести `Cold/Warm`
#
# * если > 25 → вывести `Hot`

# %%
user_input = eval(input('enter a number: '))
if user_input < 0:
    print('freezing')
elif 0 <= user_input <= 25 :
    print('cold/warm')
else:
    print('hot')

# %% [markdown]
# 3. Напишите программу, которая запрашивает число и проверяет, является ли оно чётным или нечётным.
# Вывести `Even` или `Odd`.

# %%
user_input = eval(input('enter a number: '))
if user_input % 2 == 0:
    print('even number')
else:
    print('odd number')

# %% [markdown]
# 4. Попросите пользователя ввести год и определите, является ли он високосным.
# Вывести `Leap year` или `Not leap year`.
#
# (подсказка: делится на 4, но не на 100, или делится на 400)

# %%
user_input = int(input('enter a number: '))
if ((user_input % 4 == 0) and (user_input % 100 != 0)) or user_input % 400 == 0:
    print('leap year')
else:
    print('not leap year')

# %% [markdown]
# # Python Syntax
#
# Here are some properties of Python syntax:
#
# * Statements execute one after another, until you say otherwise. Python normally
# runs statements from first to last as a
# sequence, but statements like **if** (as well as *loops* and *exceptions*) cause the interpreter to **jump around in your code**.
#
# * Because Python's path through a program is called the **control flow**, statements such as **if** that affect it are often called **control-flow
# statements**.
#
# * Block and statement boundaries are detected automatically. As we've seen,
# there are no braces or "begin/end" delimiters around blocks of code in Python; instead, Python uses the indentation of statements under a **header** to group the
# statements in a **nested block**.
#
# * Python statements are not normally terminated
# with *semicolons (;)*, the end of a line usually marks the end of the
# statement coded on that line. As a special case, statements can span lines and be combined on a line with special syntax.
#
# * **Compound statements** = header + “:” + indented statements. All Python compound
# statements, those with nested statements, follow the same pattern: a **header line** terminated with a **colon**, followed by one or more nested statements,
# usually indented under the header. The **indented statements** are called a **block**.
#
# * In the **if** statement, the **elif** and **else** clauses are part of the **if**, but they are also **header lines** with nested blocks of their own.
#
# * **Blank lines, spaces, and comments are usually ignored**. Blank lines are both
# optional and ignored in files. Spaces inside statements and expressions are almost always ignored (except in string literals, and when used for indentation)
#
# * **Comments are always ignored**: they start with a **#** character (not inside a string literal) and extend to the end of the current line.
#
# * Statements may span multiple lines if you're continuing an open syntactic
# pair `()`, `{}`, `[]`.

# %% [markdown]
# For example, suppose we want to calculate the value of this expression
# $\frac{e^{y-y^2} + 4}{\ln 25}$

# %%
import math
y = 2

x = (math.exp(y - y ** 2) + 4
     ) / (math.log(25))
print(x)

# %% [markdown]
# * Statements may span multiple lines if they end in a backslash (`\`).

# %%
x = 1 + 2 + 3 + 4 +
5 + 6

# %%
x = 1 + 2 + 3 + 4 +\
5 + 6
print(x)

# %% [markdown]
# Missing the backslash can cause a bug.

# %%
x = 1 + 2 + 3 + 4
+5 + 6
print(x)

# %%
a = 2
b = 3
c = 4
d = 5
e = 2
if a == b and c == d or \
a == e:
  print('yes!')

# %% [markdown]
# Parentheses can also be used for this purpose:

# %%
if (a == b and c == d or
    a == e):
  print('yes!')

# %% [markdown]
# # Random numbers
#
# Python has a built-in module called random that can be used to make random numbers.
#
# В Python есть встроенный модуль random, который можно использовать для генерации случайных чисел.

# %%
import random
print(random.randint(1, 90))
# random.randrange(1, 3)
# Out:
# 70

# %%
print(random.random()) # random number between [0, 1)
# Out:
# 0.07864037707148341

# %%
random.uniform(0.1,10.9)
# Out:
# 7.35538983908942

# %%
# selecting a random number from a sequence
print(random.choice([0, 1, 2]))

# %%
# 6 integers from 1 to 99
print(random.sample(range(1, 100), 6))

# %% [markdown]
# In this lesson we will learn about Python's two main **looping constructs** - statements that repeat an action over and
# over.
#
# В этом уроке мы изучим два основных цикла в Python — конструкции, которые позволяют повторять одно и то же действие снова и снова.
